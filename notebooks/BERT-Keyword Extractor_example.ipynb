# %% [markdown]
# # Keyword-Extraction using BERT

# %% [markdown]
# Use BERT Token Classification Model to extract keyword tokens from a sentence.

# %%
# Added to existing document in order to run and reproduce results
# !pip install nltk
# !pip install torch==1.0.0
# !pip install pytorch-pretrained-bert==0.4.0
# !pip install jupyter numpy pandas scikit-learn
# !pip install keras
# !pip install tensorflow
# !pip install seqeval
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nltk) (4.67.1)
# ERROR: Could not find a version that satisfies the requirement torch==1.0.0 (from versions: 1.9.0, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0)
# ERROR: No matching distribution found for torch==1.0.0
# Requirement already satisfied: pytorch-pretrained-bert==0.4.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: torch>=0.4.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.4.0) (2.8.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.4.0) (2.0.2)
# Requirement already satisfied: boto3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.4.0) (1.40.40)
# Requirement already satisfied: requests in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.4.0) (2.32.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pytorch-pretrained-bert==0.4.0) (4.67.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (1.3.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.40 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.4.0) (1.40.40)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.4.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from boto3->pytorch-pretrained-bert==0.4.0) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from botocore<1.41.0,>=1.40.40->boto3->pytorch-pretrained-bert==0.4.0) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from botocore<1.41.0,>=1.40.40->boto3->pytorch-pretrained-bert==0.4.0) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.40->boto3->pytorch-pretrained-bert==0.4.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jinja2->torch>=0.4.1->pytorch-pretrained-bert==0.4.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.4.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.4.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests->pytorch-pretrained-bert==0.4.0) (2025.8.3)
# Requirement already satisfied: jupyter in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (2.3.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (7.4.7)
# Requirement already satisfied: jupyter-console in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (6.30.1)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter) (4.4.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: appnope>=0.1.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (8.18.1)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=8.0.0->ipykernel->jupyter) (3.23.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (4.14.0)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.26.20)
# Requirement already satisfied: lark>=1.2.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: keras in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (3.10.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (14.1.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.20.0->tensorflow) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Requirement already satisfied: seqeval in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from seqeval) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from seqeval) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/pubmed_env/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)

# %% [markdown]
# ## Prepare Dataset for BERT.
#
# Convert Sem-Eval 2010 keyword recognition dataset to BIO format dataset.

# %%
import os
from nltk.tokenize import sent_tokenize
import abbreviation
from abbreviation import limits

# %%
train_path = "maui-semeval2010-train"

# %%
txt = sorted([f for f in os.listdir(train_path) if not f.endswith("-justTitle.txt") and not f.endswith(".key") and not f.endswith("-CrowdCountskey")])
key = sorted([f for f in os.listdir(train_path) if f.endswith(".key")])

# %%
filekey = dict()
for i, k in enumerate(txt):
    filekey[key[i]] = k

# %%
def convert(key):
    sentences = ""
    for line in open(train_path + "/" + filekey[key], 'r'):
        sentences += (" " + line.rstrip())
    tokens = sent_tokenize(sentences)
    key_file = open(train_path + "/" + str(key),'r')
    keys = [line.strip() for line in key_file]
    key_sent = []
    labels = []

    for token in tokens:
        
        for word in token.split():
            
            if word.lower() in limits:
                token = token.replace(word, limits[word.lower()])
             
        punctuations = '''!()-[]{};:\,<>'"./?@#$%^&*_~'''

 

        no_punct = ""
        for char in token:
            if char not in punctuations:
                no_punct = no_punct + char
        

        
        token=no_punct
       
        z = ['O'] * len(token.split())
        for k in keys:

            if k in token.lower():

                if len(k.split())==1:
                    try:
                        
                        z[token.lower().split().index(k.lower().split()[0])] = 'B'

                    except ValueError:
                        continue
                        
                    
                elif len(k.split())>1:

                    try:
                        h = k.split()
                        def index(arr, num):
                            a = []
                            for i, x in enumerate(arr):
                                if x == num:
                                    a.append(i)
                            return(a)

                     
                            
                            
                        lis1 = index(token.lower().split(),k.lower().split()[0])
                        lis2 =  index(token.lower().split(),k.lower().split()[1])
                        x = []
                        for i in lis1:
                            for j in lis2:
                                if abs(i - j) == 1:
                                    x.append(i)
                        num = x[0]  
                        z[num] = 'B'
                        
                        for j in range(1, len(h)):
                            z[num + j] = 'I'
                            
                    except:
                        continue
                     
            elif k.lower().split()[0] in token.lower():
                
                    try:
                        h = k.split()
#                         print(token)
#                         print(len(token.split()))
                        def index(arr, num):
                            a = []
                            for i, x in enumerate(arr):
                                if x == num:
                                    a.append(i)
                            return(a)

                     
                            
                            
                        lis1 = index(token.lower().split(),k.lower().split()[0])
                        lis2 =  index(token.lower().split(),k.lower().split()[1])
                        x = []
                        for i in lis1:
                            for j in lis2:
                                if abs(i - j) == 1:
                                    x.append(i)
                                    
                        num = x[0]  
                        z[num] = 'B'
                        p= len(h)-1
                        y=0
                        for j in range(1,len(token.split())):
                            if (k.lower().split()[j] in token.lower().split()):
#                                 print('rahul')
                                print(j)
                                z[num + j] = 'I'
                                print(k.lower().split()[j])
                                y+=1
                                if y==p:
                                  break
                            else:
                                continue
                            
                    except:
                        continue      
        
        for m, n in enumerate(z):
            if z[m] == 'I' and z[m-1] == 'O':
                z[m] = 'O'

        if set(z) != {'O'}:
            labels.append(z) 
            key_sent.append(token)
    return key_sent, labels

# %%
sentences_ = []
labels_ = []
for key, value in filekey.items():
    s, l = convert(key)
    sentences_.append(s)
    labels_.append(l)
sentences = [item for sublist in sentences_ for item in sublist]
labels = [item for sublist in labels_ for item in sublist]
# print(len(sentences), len(labels))
# Out:
# 1
# control
# 1
# of
# 1
# control
# 1
# of
# 1
# control
# 1
# resource
# 2
# management
# 1
# grid
# 1
# grid
# 3
# environment
# 1
# grid
# 1
# grid
# 1
# gridway
# 1
# grid
# 1
# grid
# 1
# sensor
# 1
# sequence
# 1
# sensor
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 2
# process
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# sequence
# 1
# of
# 1
# index
# 1
# of
# 1
# index
# 1
# of
# 1
# index
# 1
# index
# 1
# index
# 2
# structure
# 1
# skip
# 1
# index
# 1
# of
# 1
# index
# 1
# range
# 1
# range
# 1
# range
# 2
# query
# 1
# range
# 1
# range
# 1
# range
# 1
# range
# 1
# storage
# 1
# range
# 1
# range
# 1
# storage
# 1
# range
# 1
# range
# 1
# range
# 1
# range
# 1
# storage
# 1
# range
# 1
# range
# 1
# storage
# 1
# storage
# 1
# mobility
# 1
# of
# 1
# of
# 2
# past
# 4
# and
# 5
# transitivity
# 1
# tracking
# 1
# tracking
# 1
# tracking
# 1
# tracking
# 1
# tracking
# 1
# and
# 1
# tracking
# 1
# and
# 1
# based
# 1
# based
# 1
# based
# 1
# based
# 2
# algorithm
# 1
# spatial
# 1
# spatial
# 1
# spatial
# 1
# spatial
# 1
# contextdimension
# 1
# configuration
# 1
# support
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 1
# strategy
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 1
# strategy
# 2
# nash
# 1
# strategy
# 1
# strategy
# 3
# equilibrium
# 1
# strategy
# 2
# nash
# 1
# strategy
# 1
# strategy
# 2
# nash
# 1
# strategy
# 2
# nash
# 1
# strategy
# 1
# strategy
#
# strategy
# 1
# elimination
# 2
# of
# 3
# weakly
# 4
# dominated
# 5
# strategy
# 1
# dominated
# 2
# strategy
# 3
# iterative
# 4
# elimination
# 1
# elimination
# 2
# of
# 3
# weakly
# 4
# dominated
# 5
# strategy
# 1
# dominated
# 2
# strategy
# 3
# iterative
# 4
# elimination
# 1
# elimination
# 2
# of
# 3
# weakly
# 4
# dominated
# 1
# dominated
# 3
# 1
# strategy
# 1
# and
# 2
# seller
# 1
# combinatorial
# 1
# choice
# 1
# truthful
# 2
# market
# 1
# and
# 1
# and
# 2
# seller
# 1
# and
# 1
# and
# 2
# seller
# 1
# and
# 2
# seller
# 1
# market
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# enhancing
# 2
# 1
# information
# 1
# information
# 2
# protection
# 1
# information
# 1
# decision
# 2
# making
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# information
# 1
# enhancing
# 1
# information
# 1
# enhancing
# 1
# enhancing
# 1
# enhancing
# 1
# willingness
# 1
# scheduling
# 1
# scheduling
# 1
# scheduling
# 2
# of
# 1
# stranger
# 1
# adaptive
# 1
# adaptive
# 1
# adaptive
# 1
# adaptive
# 1
# nominal
# 1
# stranger
# 1
# stranger
# 1
# stranger
# 1
# for
# 1
# stranger
# 2
# policy
# 1
# stranger
# 2
# policy
# 1
# stranger
# 2
# policy
# 1
# stranger
# 1
# stranger
# 1
# auction
# 1
# auction
# 1
# auction
# 1
# elicitation
# 1
# elicitation
# 1
# number
# 2
# of
# 1
# auction
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# number
# 2
# of
# 1
# elicitation
# 1
# elicitation
# 1
# auction
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# auction
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 2
# algorithm
# 1
# number
# 2
# of
# 1
# elicitation
# 1
# number
# 2
# of
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# auction
# 1
# number
# 2
# of
# 1
# number
# 2
# of
# 1
# elicitation
# 1
# elicitation
# 2
# 1
# elicitation
# 1
# elicitation
# 2
# 1
# elicitation
# 1
# number
# 2
# of
# 1
# elicitation
# 1
# auction
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# elicitation
# 1
# weighted
# 2
# average
# 3
# price
# 4
# trading
# 1
# order
# 3
# trading
# 1
# weighted
# 2
# average
# 3
# price
# 4
# trading
# 1
# order
# 3
# trading
# 4
# model
# 1
# order
# 3
# trading
# 1
# order
# 3
# trading
# 4
# model
# 1
# of
# 1
# order
# 2
# book
# 3
# trading
# 1
# order
# 3
# trading
# 1
# order
# 1
# order
# 2
# book
# 1
# order
# 2
# book
# 1
# order
# 1
# order
# 1
# order
# 1
# of
# 1
# order
# 1
# order
# 3
# trading
# 1
# order
# 2
# book
# 1
# order
# 1
# of
# 1
# order
# 1
# order
# 1
# order
# 1
# of
# 1
# of
# 1
# of
# 1
# order
# 1
# of
# 1
# of
# 1
# order
# 1
# order
# 1
# of
# 1
# order
# 1
# of
# 1
# order
# 1
# order
# 1
# order
# 1
# order
# 1
# order

# %% [markdown]
# ## Model

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, trange
import torch
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.nn.utils.rnn import pad_sequence
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pytorch_pretrained_bert import BertTokenizer, BertConfig
from pytorch_pretrained_bert import BertForTokenClassification, BertAdam

# %%
MAX_LEN = 75
bs = 32

# %%
tag2idx = {'B': 0, 'I': 1, 'O': 2}
tags_vals = ['B', 'I', 'O']

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# %%
tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]

# %%
input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                          maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")
tags = pad_sequences([[tag2idx.get(l) for l in lab] for lab in labels],
                     maxlen=MAX_LEN, value=tag2idx["O"], padding="post",
                     dtype="long", truncating="post")

# %%
attention_masks = [[float(i>0) for i in ii] for ii in input_ids]

# %%
tr_inputs, val_inputs, tr_tags, val_tags = train_test_split(input_ids, tags, 
                                                            random_state=2018, test_size=0.1)
tr_masks, val_masks, _, _ = train_test_split(attention_masks, input_ids,
                                             random_state=2018, test_size=0.1)

# %%
tr_inputs = torch.tensor(tr_inputs)
val_inputs = torch.tensor(val_inputs)
tr_tags = torch.tensor(tr_tags)
val_tags = torch.tensor(val_tags)
tr_masks = torch.tensor(tr_masks)
val_masks = torch.tensor(val_masks)

# %%
train_data = TensorDataset(tr_inputs, tr_masks, tr_tags)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=bs)

valid_data = TensorDataset(val_inputs, val_masks, val_tags)
valid_sampler = SequentialSampler(valid_data)
valid_dataloader = DataLoader(valid_data, sampler=valid_sampler, batch_size=bs)

# %%
model = BertForTokenClassification.from_pretrained("bert-base-uncased", num_labels=len(tag2idx))

# %%
# adjusted to run locally with cpu

device = torch.device("cpu")
model = model.to(device)
tr_inputs = tr_inputs.to(device)
tr_masks = tr_masks.to(device)
tr_tags = tr_tags.to(device)

# %%
FULL_FINETUNING = True
if FULL_FINETUNING:
    param_optimizer = list(model.named_parameters())
    no_decay = ['bias', 'gamma', 'beta']
    optimizer_grouped_parameters = [
        {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)],
         'weight_decay_rate': 0.01},
        {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)],
         'weight_decay_rate': 0.0}
    ]
else:
    param_optimizer = list(model.classifier.named_parameters()) 
    optimizer_grouped_parameters = [{"params": [p for n, p in param_optimizer]}]
optimizer = Adam(optimizer_grouped_parameters, lr=3e-5)

# %%
from seqeval.metrics import f1_score

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=2).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from tqdm import tqdm
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

epochs = 4
bs = 16  # example batch size
clip_value = 1.0

# Training loop
for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}\n")

    # --- Training ---
    model.train()
    train_loss = 0.0

    train_iterator = tqdm(train_dataloader, desc="Training", leave=False)
    for batch in train_iterator:
        b_input_ids, b_input_mask, b_labels = [t.to(device) for t in batch]

        optimizer.zero_grad()
        outputs = model(
            input_ids=b_input_ids,
            attention_mask=b_input_mask,
            labels=b_labels
        )

        # Safe loss handling
        loss = outputs.loss if hasattr(outputs, "loss") else outputs
        train_loss += loss.item()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip_value)
        optimizer.step()

        train_iterator.set_postfix({"loss": f"{loss.item():.4f}"})

    avg_train_loss = train_loss / len(train_dataloader)
    print(f"Average Training Loss: {avg_train_loss:.4f}")

    # --- Validation ---
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        val_iterator = tqdm(valid_dataloader, desc="Validation", leave=False)
        for batch in val_iterator:
            b_input_ids, b_input_mask, b_labels = [t.to(device) for t in batch]

            outputs = model(
                input_ids=b_input_ids,
                attention_mask=b_input_mask,
                labels=b_labels
            )

            loss = outputs.loss if hasattr(outputs, "loss") else outputs
            val_loss += loss.item()
            val_iterator.set_postfix({"val_loss": f"{loss.item():.4f}"})

    avg_val_loss = val_loss / len(valid_dataloader)
    print(f"Validation Loss: {avg_val_loss:.4f}")
# Out:
# Epoch 1/4
# Average Training Loss: 0.0829
# Validation Loss: 0.0559
#
# Epoch 2/4
# Average Training Loss: 0.0480
# Validation Loss: 0.0411
#
# Epoch 3/4
# Average Training Loss: 0.0337
# Validation Loss: 0.0363
#
# Epoch 4/4
# Average Training Loss: 0.0252
# Validation Loss: 0.0339

# %% [markdown]
# .

# %% [markdown]
# ### Get keywords from sentence

# %%
def keywordextract(sentence):
    text = sentence
    tkns = tokenizer.tokenize(text)
    indexed_tokens = tokenizer.convert_tokens_to_ids(tkns)
    segments_ids = [0] * len(tkns)
    tokens_tensor = torch.tensor([indexed_tokens]).to(device)
    segments_tensors = torch.tensor([segments_ids]).to(device)
    model.eval()
    prediction = []
    logit = model(tokens_tensor, token_type_ids=None,
                                  attention_mask=segments_tensors)
    logit = logit.detach().cpu().numpy()
    prediction.extend([list(p) for p in np.argmax(logit, axis=2)])
    for k, j in enumerate(prediction[0]):
        if j==1 or j==0:
            print(tokenizer.convert_ids_to_tokens(tokens_tensor[0].to('cpu').numpy())[k], j)

# %%
text = "The solution is based upon an abstract representation of the mobile object system."

# %%
keywordextract(text)
# Out:
# mobile 0
# object 1
